# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import KFold
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.linear_model import ElasticNet
from sklearn.model_selection import cross_val_score
pd.set_option('Display.max_columns', 230)
pd.set_option('display.width', 45)

# %%
dados = pd.read_csv('C:\\Users\\reisg\\OneDrive\\Área de Trabalho\\Aquivos_importantes\\Treinamento\\Exerc_8\\Admission_Predict.csv')
dados.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  \
# 0           1        337          118
# 1           2        324          107
# 2           3        316          104
# 3           4        322          110
# 4           5        314          103
#
#    University Rating  SOP  LOR   CGPA  \
# 0                  4  4.5   4.5  9.65
# 1                  4  4.0   4.5  8.87
# 2                  3  3.0   3.5  8.00
# 3                  3  3.5   2.5  8.67
# 4                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
dados.drop('Serial No.', axis= 1, inplace=True)

# %%
dados.head()
# Out:
#    GRE Score  TOEFL Score  \
# 0        337          118
# 1        324          107
# 2        316          104
# 3        322          110
# 4        314          103
#
#    University Rating  SOP  LOR   CGPA  \
# 0                  4  4.5   4.5  9.65
# 1                  4  4.0   4.5  8.87
# 2                  3  3.0   3.5  8.00
# 3                  3  3.5   2.5  8.67
# 4                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
y = dados['Chance of Admit ']
x = dados.drop('Chance of Admit ', axis=1)

# %%
kfold = KFold(n_splits=10)
modelo = ElasticNet()
modelo_02 = LinearRegression()
modelo_03 = Ridge()
modelo_04 = Lasso()

# %%
cross_val_score(modelo_02,x,y, cv=kfold).mean()
# Out:
# 0.7703825020879949

# %%
valores = {'alpha':[0.26,0.450,0.0025], 'l1_ratio':[0.01,0.005,0.241]}
resultado = RandomizedSearchCV(estimator=modelo,param_distributions=valores,n_iter=9, cv=kfold)
resultado.fit(x,y)
# Out:
# RandomizedSearchCV(cv=KFold(n_splits=10, random_state=None, shuffle=False),
#                    estimator=ElasticNet(), n_iter=9,
#                    param_distributions={'alpha': [0.26, 0.45, 0.0025],
#                                         'l1_ratio': [0.01, 0.005, 0.241]})

# %%
print(f'Melhor alpha: {resultado.best_estimator_.alpha} | Melhor l1_ratio: {resultado.best_estimator_.l1_ratio} | Melhor score: {resultado.best_score_}')
# Out:
# Melhor alpha: 0.0025 | Melhor l1_ratio: 0.241 | Melhor score: 0.7712703642517125

# %%
resultado_02 = GridSearchCV(estimator=modelo, param_grid=valores,cv=kfold) 
resultado_02.fit(x,y)
# Out:
# GridSearchCV(cv=KFold(n_splits=10, random_state=None, shuffle=False),
#              estimator=ElasticNet(),
#              param_grid={'alpha': [0.26, 0.45, 0.0025],
#                          'l1_ratio': [0.01, 0.005, 0.241]})

# %%
print(f'Melhor alpha: {resultado_02.best_estimator_.alpha} | Melhor l1_ratio: {resultado_02.best_estimator_.l1_ratio} | Melhor score: {resultado_02.best_score_}')
# Out:
# Melhor alpha: 0.0025 | Melhor l1_ratio: 0.241 | Melhor score: 0.7712703642517125
